# %%
import pickle

# %%
f = open('totalDict.data', 'r')
rdata = pickle.load(f)
f.close()

# %%
res = "1 2 3 4 5 1 2 3"
rdd = sc.parallelize(res)
result = rdd.flatMap(lambda line: line.split(" ")) \
             .map(lambda word: (word, 1)) \
             .reduceByKey(lambda a, b: a + b)
result.saveAsTextFile("res.log")

# %%
for item in rdata['time'][::33]:
    print item.split(" ")
# Out:
# ['2015-08-15', '19:50']
# ['2015-08-11']
# ['2015-08-06']
# ['2015-08-02']
# ['2015-07-30']
# ['2015-07-27']
# ['2015-07-22']
# ['2015-07-18']
# ['2015-07-15']
# ['2015-07-09']
# ['2015-07-05']
# ['2015-07-03']
# ['2015-06-30']
# ['2015-06-28']
# ['2015-06-26']
# ['2015-06-23']
# ['2015-06-19']
# ['2015-06-18']
# ['2015-06-16']
# ['2015-06-13']
# ['2015-06-10']
# ['2015-06-08']
# ['2015-06-06']
# ['2015-06-04']
# ['2015-06-03']
# ['2015-06-01']
# ['2015-05-29']
# ['2015-05-28']
# ['2015-05-27']
# ['2015-05-24']
# ['2015-05-22']
# ['2015-05-21']
# ['2015-05-19']
# ['2015-05-16']
# ['2015-05-15']
# ['2015-05-13']
# ['2015-05-12']
# ['2015-05-11']
# ['2015-05-10']
# ['2015-05-08']
# ['2015-05-06']
# ['2015-05-05']
# ['2015-05-03']
# ['2015-05-01']
# ['2015-04-30']
# ['2015-04-28']
# ['2015-04-26']
# ['2015-04-24']
# ['2015-04-22']
# ['2015-04-20']
# ['2015-04-18']
# ['2015-04-15']
# ['2015-04-14']
# ['2015-04-12']
# ['2015-04-10']
# ['2015-04-08']
# ['2015-04-07']
# ['2015-04-04']
# ...
